# %%
# !pip install pulp
import pandas as pd
import numpy as np
from pulp import LpProblem, LpVariable, lpSum, LpMaximize, LpStatus, GLPK
from tabulate import tabulate
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.12/dist-packages (3.2.2)

# %%
# Load data from the specified URL
url = 'https://raw.githubusercontent.com/PhuphaB/Dissertation/main/ESPN_Top_40_Players.csv'
data = pd.read_csv(url, skiprows=[0]) # Skip the first row

# %%
# Rename columns for easier access
data.columns = [
    'ESPN_Ranking', 'Player', 'Team', 'Team_IG_Followers_M',
    'PER', 'Minutes_Played', 'Clutch_PPG', 'Win_Shares',
    'True_Shooting_Pct', 'IG_Growth_Pct', 'IG_Engagement_Pct',
    'Player_IG_Followers_M', 'Google_Trends_Score', 'All_Star_Votes_M'
]

# Check updated column names
data.head()
# Out:
#    ESPN_Ranking                   Player                   Team  \
# 0             2              Luka Doncic     Los Angeles Lakers
# 1             3    Giannis Antetokounmpo       Milwaukee Bucks
# 2             4  Shai Gilgeous-Alexander  Oklahoma City Thunder
# 3             5             Jayson Tatum         Boston Celtics
# 4             6           Stephen Curry   Golden State Warriors
#
#    Team_IG_Followers_M   PER  Minutes_Played  Clutch_PPG  Win_Shares  \
# 0                25.32  24.1            1769         1.9         5.9
# 1                 5.50  30.5            2289         2.9        11.5
# 2                 6.16  30.7            2598         3.0        16.7
# 3                 8.46  21.7            2624         3.0         9.5
# 4                32.72  21.5            2252         3.6         7.9
#
#    True_Shooting_Pct  IG_Growth_Pct  IG_Engagement_Pct  Player_IG_Followers_M  \
# 0               58.7          24.00               7.12                  10.49
# 1               62.5           1.26               1.79                  15.99
# 2               63.7          69.19              10.73                   4.01
# 3               58.2          10.60               5.22                   7.30
# 4               61.8           6.20               0.77                  58.11
#
#    Google_Trends_Score  All_Star_Votes_M
# 0                 5.58              2.03
# 1                32.74              4.44
# 2                41.52              3.15
# 3                32.02              3.61
# 4                29.29              2.34

# %%
def run_dea(inputs_df, outputs_df, ar_constraint=False, return_weights=False, ar_lower_bound=0.05):
    """
    A single, master function to perform DEA.
    """
    inputs = inputs_df.values
    outputs = outputs_df.values
    player_names = data['Player'].values
    num_players = len(player_names)
    num_inputs = inputs_df.shape[1]
    num_outputs = outputs_df.shape[1]

    efficiency_scores = {}
    optimal_weights = {}

    for i in range(num_players):
        prob = LpProblem(f"DEA_Player_{i}", LpMaximize)
        u = [LpVariable(f"u_{r}_{i}", lowBound=0) for r in range(num_outputs)]
        v = [LpVariable(f"v_{s}_{i}", lowBound=0) for s in range(num_inputs)]

        prob += lpSum(u[r] * outputs[i, r] for r in range(num_outputs))
        prob += lpSum(v[s] * inputs[i, s] for s in range(num_inputs)) == 1

        for j in range(num_players):
            prob += lpSum(u[r] * outputs[j, r] for r in range(num_outputs)) - \
                    lpSum(v[s] * inputs[j, s] for s in range(num_inputs)) <= 0

        if ar_constraint:
            sum_of_u_weights = lpSum(u)
            for r in range(num_outputs):
                prob += u[r] >= ar_lower_bound * sum_of_u_weights

        prob.solve()

        if LpStatus[prob.status] == 'Optimal':
            efficiency_scores[player_names[i]] = prob.objective.value()
            if return_weights:
                optimal_weights[player_names[i]] = {
                    'u': [var.value() for var in u],
                    'v': [var.value() for var in v]
                }
        else:
            efficiency_scores[player_names[i]] = None
            if return_weights:
                optimal_weights[player_names[i]] = None

    results_df = pd.DataFrame(list(efficiency_scores.items()), columns=['Player', 'Efficiency_Score'])

    if return_weights:
        return results_df, optimal_weights
    else:
        return results_df

# %% [markdown]
# #Model 4 (Without Cumulative Statistic)

# %%
# Define inputs for Model 4 (only rate-based statistics)
input_cols_m4 = ['PER', 'True_Shooting_Pct', 'Clutch_PPG']
output_cols_m4 = ['IG_Growth_Pct', 'IG_Engagement_Pct', 'Player_IG_Followers_M', 'All_Star_Votes_M', 'Google_Trends_Score']
model4_inputs = data[input_cols_m4]
model4_outputs = data[output_cols_m4]

# %%
# Run Dea Model 4
model4_scores, model4_weights = run_dea(model4_inputs, model4_outputs, ar_constraint=True, return_weights=True)
model4_scores = model4_scores.sort_values(by='Efficiency_Score', ascending=False).reset_index(drop=True)

# %%
# Show and Save Scores
print("\n--- Results: Model 4 (Standard AR Scores) ---")
print(tabulate(model4_scores, headers='keys', tablefmt='fancy_grid', showindex=False))
model4_scores.to_csv('model_4_with_ar_scores.csv', index=False)
print("\nStandard AR scores saved to 'model_4_with_ar_scores.csv'")
# Out:
# --- Results: Model 4 (Standard AR Scores) ---
# ╒═════════════════════════╤════════════════════╕
# │ Player                  │   Efficiency_Score │
# ╞═════════════════════════╪════════════════════╡
# │ Tyrese Haliburton       │           1        │
# ├─────────────────────────┼────────────────────┤
# │ Victor Wembenyama       │           1        │
# ├─────────────────────────┼────────────────────┤
# │ Devin Booker            │           1        │
# ├─────────────────────────┼────────────────────┤
# │ Anthony Edwards         │           1        │
# ├─────────────────────────┼────────────────────┤
# │ Chet Holmgren           │           1        │
# ├─────────────────────────┼────────────────────┤
# │ Lebron James            │           1        │
# ├─────────────────────────┼────────────────────┤
# │ Jrue Holiday            │           1        │
# ├─────────────────────────┼────────────────────┤
# │ Karl-Anthony Towns      │           0.981675 │
# ├─────────────────────────┼────────────────────┤
# │ Anthony Davis           │           0.939672 │
# ├─────────────────────────┼────────────────────┤
# │ Kawhi Leonard           │           0.939269 │
# ├─────────────────────────┼────────────────────┤
# │ Shai Gilgeous-Alexander │           0.911458 │
# ├─────────────────────────┼────────────────────┤
# │ Jalen Brunson           │           0.841806 │
# ├─────────────────────────┼────────────────────┤
# │ Kevin Durant            │           0.776848 │
# ├─────────────────────────┼────────────────────┤
# │ Mikal Bridges           │           0.751639 │
# ├─────────────────────────┼────────────────────┤
# │ Paul George             │           0.707214 │
# ├─────────────────────────┼────────────────────┤
# │ Stephen Curry           │           0.701873 │
# ├─────────────────────────┼────────────────────┤
# │ James Harden            │           0.689328 │
# ├─────────────────────────┼────────────────────┤
# │ Derrick White           │           0.671371 │
# ├─────────────────────────┼────────────────────┤
# │ Jayson Tatum            │           0.628392 │
# ├─────────────────────────┼────────────────────┤
# │ Giannis Antetokounmpo   │           0.627373 │
# ├─────────────────────────┼────────────────────┤
# │ Luka Doncic             │           0.569061 │
# ├─────────────────────────┼────────────────────┤
# │ Donovan Mitchell        │           0.53999  │
# ├─────────────────────────┼────────────────────┤
# │ Scottie Barnes          │           0.516638 │
# ├─────────────────────────┼────────────────────┤
# │ Damian Lillard          │           0.50559  │
# ├─────────────────────────┼────────────────────┤
# │ Brandon Ingram          │           0.450929 │
# ├─────────────────────────┼────────────────────┤
# │ Bam Adebayo             │           0.447945 │
# ├─────────────────────────┼────────────────────┤
# │ Tyrese Maxey            │           0.427674 │
# ├─────────────────────────┼────────────────────┤
# │ Domantas Sabonis        │           0.426093 │
# ├─────────────────────────┼────────────────────┤
# │ Lauri Markkanen         │           0.409483 │
# ├─────────────────────────┼────────────────────┤
# │ Ja Morant               │           0.405364 │
# ├─────────────────────────┼────────────────────┤
# │ Paolo Banchero          │           0.397222 │
# ├─────────────────────────┼────────────────────┤
# │ Zion Williamson         │           0.395532 │
# ├─────────────────────────┼────────────────────┤
# │ De'Aaron Fox            │           0.395323 │
# ├─────────────────────────┼────────────────────┤
# │ Jaylen Brown            │           0.365624 │
# ├─────────────────────────┼────────────────────┤
# │ Kyrie Irving            │           0.342872 │
# ├─────────────────────────┼────────────────────┤
# │ Rudy Gobert             │           0.339244 │
# ├─────────────────────────┼────────────────────┤
# │ Jamal Murray            │           0.320416 │
# ├─────────────────────────┼────────────────────┤
# │ Joel Embiid             │           0.308474 │
# ├─────────────────────────┼────────────────────┤
# │ Trae Young              │           0.227994 │
# ├─────────────────────────┼────────────────────┤
# │ Jimmy Butler            │           0.190691 │
# ╘═════════════════════════╧════════════════════╛
#
# Standard AR scores saved to 'model_4_with_ar_scores.csv'

# %%
# Process and Save Weights
weights_data_m4 = []
for player, w in model4_weights.items():
    if w:
        row = {'Player': player}
        for i, col in enumerate(output_cols_m4):
            row[f'u_{col}'] = w['u'][i]
        for i, col in enumerate(input_cols_m4):
            row[f'v_{col}'] = w['v'][i]
        weights_data_m4.append(row)
weights_df_m4 = pd.DataFrame(weights_data_m4)
weights_df_m4.to_csv('model_4_with_ar_weights.csv', index=False)
print("Optimal weights saved to 'model_4_with_ar_weights.csv'\n")
# Out:
# Optimal weights saved to 'model_4_with_ar_weights.csv'

# %% [markdown]
# #Cross Efficiency Matrix

# %%
def calculate_cross_efficiency(inputs_df, outputs_df, all_weights):
    """Calculates the cross-efficiency matrix and final average scores."""
    inputs = inputs_df.values
    outputs = outputs_df.values
    player_names = data['Player'].values
    num_players = len(player_names)
    cross_efficiency_matrix = np.zeros((num_players, num_players))

    for i, i_player_name in enumerate(player_names):
        weights = all_weights.get(i_player_name)
        if weights is None: continue
        evaluator_u, evaluator_v = weights['u'], weights['v']

        for j, j_player_name in enumerate(player_names):
            weighted_outputs = np.sum(outputs[j, :] * evaluator_u)
            weighted_inputs = np.sum(inputs[j, :] * evaluator_v)
            score = weighted_outputs / weighted_inputs if weighted_inputs != 0 else 0
            cross_efficiency_matrix[i, j] = score

    final_cross_scores = np.mean(cross_efficiency_matrix, axis=0)
    scores_df = pd.DataFrame({'Player': player_names, 'Cross_Efficiency_Score': final_cross_scores})
    matrix_df = pd.DataFrame(cross_efficiency_matrix, index=player_names, columns=player_names)
    return matrix_df, scores_df

# %%
# Run Cross Efficiency Analysis
m4_matrix_df, m4_scores_df = calculate_cross_efficiency(model4_inputs, model4_outputs, model4_weights)

# %%
# Display and Save Full Matrix
print("\n--- Full Cross-Efficiency Matrix (Model 4) ---")
print(m4_matrix_df.round(3))
m4_matrix_df.to_csv('model_4_cross_efficiency_matrix.csv')
print("\nFull matrix saved to 'model_4_cross_efficiency_matrix.csv'")
# Out:
# --- Full Cross-Efficiency Matrix (Model 4) ---
#                          Luka Doncic  Giannis Antetokounmpo  \
# Luka Doncic                    0.569                  0.444
# Giannis Antetokounmpo          0.212                  0.627
# Shai Gilgeous-Alexander        0.445                  0.435
# Jayson Tatum                   0.193                  0.625
# Stephen Curry                  0.158                  0.458
# Lebron James                   0.075                  0.085
# Joel Embiid                    0.221                  0.615
# Kevin Durant                   0.189                  0.597
# Anthony Edwards                0.250                  0.198
# Victor Wembenyama              0.431                  0.179
# Jalen Brunson                  0.425                  0.187
# Anthony Davis                  0.463                  0.459
# Jaylen Brown                   0.189                  0.597
# Devin Booker                   0.157                  0.562
# Tyrese Haliburton              0.205                  0.025
# Donovan Mitchell               0.164                  0.602
# Bam Adebayo                    0.204                  0.589
# Tyrese Maxey                   0.425                  0.187
# Ja Morant                      0.447                  0.230
# Paul George                    0.194                  0.407
# Kawhi Leonard                  0.493                  0.329
# Damian Lillard                 0.212                  0.627
# Paolo Banchero                 0.425                  0.187
# Kyrie Irving                   0.466                  0.455
# De'Aaron Fox                   0.431                  0.179
# Zion Williamson                0.193                  0.625
# Jimmy Butler                   0.466                  0.455
# Domantas Sabonis               0.474                  0.493
# Karl-Anthony Towns             0.193                  0.609
# Jamal Murray                   0.445                  0.435
# Chet Holmgren                  0.487                  0.186
# Lauri Markkanen                0.431                  0.179
# Rudy Gobert                    0.484                  0.219
# Scottie Barnes                 0.445                  0.435
# Jrue Holiday                   0.204                  0.589
# Trae Young                     0.409                  0.198
# Mikal Bridges                  0.487                  0.186
# Derrick White                  0.431                  0.179
# Brandon Ingram                 0.431                  0.179
# James Harden                   0.193                  0.625
#
#                          Shai Gilgeous-Alexander  Jayson Tatum  \
# Luka Doncic                                0.804         0.470
# Giannis Antetokounmpo                      0.818         0.625
# Shai Gilgeous-Alexander                    0.911         0.549
# Jayson Tatum                               0.810         0.628
# Stephen Curry                              0.590         0.561
# Lebron James                               0.054         0.068
# Joel Embiid                                0.827         0.625
# Kevin Durant                               0.774         0.621
# Anthony Edwards                            0.568         0.230
# Victor Wembenyama                          0.620         0.403
# Jalen Brunson                              0.645         0.403
# Anthony Davis                              0.644         0.411
# Jaylen Brown                               0.774         0.621
# Devin Booker                               0.757         0.615
# Tyrese Haliburton                          0.371         0.069
# Donovan Mitchell                           0.809         0.626
# Bam Adebayo                                0.834         0.621
# Tyrese Maxey                               0.645         0.403
# Ja Morant                                  0.670         0.415
# Paul George                                0.496         0.363
# Kawhi Leonard                              0.795         0.438
# Damian Lillard                             0.818         0.625
# Paolo Banchero                             0.645         0.403
# Kyrie Irving                               0.907         0.552
# De'Aaron Fox                               0.620         0.403
# Zion Williamson                            0.810         0.628
# Jimmy Butler                               0.907         0.552
# Domantas Sabonis                           0.744         0.453
# Karl-Anthony Towns                         0.820         0.622
# Jamal Murray                               0.911         0.549
# Chet Holmgren                              0.636         0.349
# Lauri Markkanen                            0.620         0.403
# Rudy Gobert                                0.666         0.379
# Scottie Barnes                             0.911         0.549
# Jrue Holiday                               0.834         0.621
# Trae Young                                 0.569         0.397
# Mikal Bridges                              0.636         0.349
# Derrick White                              0.620         0.403
# Brandon Ingram                             0.620         0.403
# James Harden                               0.810         0.628
#
#                          Stephen Curry   Lebron James  Joel Embiid  \
# Luka Doncic                       0.417         1.000        0.200
# Giannis Antetokounmpo             0.660         1.000        0.306
# Shai Gilgeous-Alexander           0.438         0.712        0.266
# Jayson Tatum                      0.678         1.000        0.306
# Stephen Curry                     0.702         1.000        0.245
# Lebron James                      0.395         1.000        0.051
# Joel Embiid                       0.660         1.000        0.308
# Kevin Durant                      0.680         1.000        0.299
# Anthony Edwards                   0.184         0.265        0.114
# Victor Wembenyama                 0.315         0.576        0.155
# Jalen Brunson                     0.314         0.567        0.154
# Anthony Davis                     0.398         1.000        0.166
# Jaylen Brown                      0.680         1.000        0.299
# Devin Booker                      0.570         0.629        0.280
# Tyrese Haliburton                 0.050         0.073        0.011
# Donovan Mitchell                  0.573         0.642        0.290
# Bam Adebayo                       0.556         0.663        0.295
# Tyrese Maxey                      0.314         0.567        0.154
# Ja Morant                         0.471         1.000        0.172
# Paul George                       0.437         1.000        0.245
# Kawhi Leonard                     0.324         0.632        0.233
# Damian Lillard                    0.660         1.000        0.306
# Paolo Banchero                    0.314         0.567        0.154
# Kyrie Irving                      0.521         1.000        0.278
# De'Aaron Fox                      0.315         0.576        0.155
# Zion Williamson                   0.678         1.000        0.306
# Jimmy Butler                      0.521         1.000        0.278
# Domantas Sabonis                  0.428         1.000        0.191
# Karl-Anthony Towns                0.568         0.699        0.293
# Jamal Murray                      0.438         0.712        0.266
# Chet Holmgren                     0.246         0.548        0.166
# Lauri Markkanen                   0.315         0.576        0.155
# Rudy Gobert                       0.275         0.577        0.183
# Scottie Barnes                    0.438         0.712        0.266
# Jrue Holiday                      0.556         0.663        0.295
# Trae Young                        0.483         1.000        0.160
# Mikal Bridges                     0.246         0.548        0.166
# Derrick White                     0.315         0.576        0.155
# Brandon Ingram                    0.315         0.576        0.155
# James Harden                      0.678         1.000        0.306
#
#                          Kevin Durant   Anthony Edwards  Victor Wembenyama   \
# Luka Doncic                      0.497            0.950               1.000
# Giannis Antetokounmpo            0.767            1.000               0.518
# Shai Gilgeous-Alexander          0.661            1.000               1.000
# Jayson Tatum                     0.776            1.000               0.492
# Stephen Curry                    0.743            1.000               0.400
# Lebron James                     0.114            0.143               0.067
# Joel Embiid                      0.772            1.000               0.545
# Kevin Durant                     0.777            1.000               0.481
# Anthony Edwards                  0.246            1.000               0.578
# Victor Wembenyama                0.512            1.000               1.000
# Jalen Brunson                    0.495            1.000               1.000
# Anthony Davis                    0.414            0.813               0.716
# Jaylen Brown                     0.777            1.000               0.481
# Devin Booker                     0.764            1.000               0.460
# Tyrese Haliburton                0.035            0.853               0.474
# Donovan Mitchell                 0.763            1.000               0.476
# Bam Adebayo                      0.759            1.000               0.554
# Tyrese Maxey                     0.495            1.000               1.000
# Ja Morant                        0.512            1.000               1.000
# Paul George                      0.477            0.505               0.342
# Kawhi Leonard                    0.531            0.794               1.000
# Damian Lillard                   0.767            1.000               0.518
# Paolo Banchero                   0.495            1.000               1.000
# Kyrie Irving                     0.670            1.000               1.000
# De'Aaron Fox                     0.512            1.000               1.000
# Zion Williamson                  0.776            1.000               0.492
# Jimmy Butler                     0.670            1.000               1.000
# Domantas Sabonis                 0.466            1.000               0.788
# Karl-Anthony Towns               0.753            1.000               0.515
# Jamal Murray                     0.661            1.000               1.000
# Chet Holmgren                    0.430            0.742               1.000
# Lauri Markkanen                  0.512            1.000               1.000
# Rudy Gobert                      0.471            0.778               1.000
# Scottie Barnes                   0.661            1.000               1.000
# Jrue Holiday                     0.759            1.000               0.554
# Trae Young                       0.520            1.000               0.912
# Mikal Bridges                    0.430            0.742               1.000
# Derrick White                    0.512            1.000               1.000
# Brandon Ingram                   0.512            1.000               1.000
# James Harden                     0.776            1.000               0.492
#
#                          ...  Chet Holmgren   Lauri Markkanen   Rudy Gobert   \
# Luka Doncic              ...           1.000             0.204         0.242
# Giannis Antetokounmpo    ...           0.209             0.144         0.128
# Shai Gilgeous-Alexander  ...           0.627             0.299         0.227
# Jayson Tatum             ...           0.187             0.144         0.121
# Stephen Curry            ...           0.151             0.145         0.110
# Lebron James             ...           0.024             0.011         0.011
# Joel Embiid              ...           0.231             0.160         0.135
# Kevin Durant             ...           0.188             0.146         0.124
# Anthony Edwards          ...           0.916             0.056         0.128
# Victor Wembenyama        ...           0.627             0.409         0.237
# Jalen Brunson            ...           0.549             0.368         0.197
# Anthony Davis            ...           1.000             0.082         0.168
# Jaylen Brown             ...           0.188             0.146         0.124
# Devin Booker             ...           0.175             0.147         0.120
# Tyrese Haliburton        ...           0.771             0.006         0.013
# Donovan Mitchell         ...           0.175             0.144         0.116
# Bam Adebayo              ...           0.236             0.167         0.136
# Tyrese Maxey             ...           0.549             0.368         0.197
# Ja Morant                ...           0.521             0.337         0.182
# Paul George              ...           0.551             0.106         0.251
# Kawhi Leonard            ...           1.000             0.310         0.314
# Damian Lillard           ...           0.209             0.144         0.128
# Paolo Banchero           ...           0.549             0.368         0.197
# Kyrie Irving             ...           0.638             0.295         0.230
# De'Aaron Fox             ...           0.627             0.409         0.237
# Zion Williamson          ...           0.187             0.144         0.121
# Jimmy Butler             ...           0.638             0.295         0.230
# Domantas Sabonis         ...           1.000             0.090         0.179
# Karl-Anthony Towns       ...           0.206             0.144         0.126
# Jamal Murray             ...           0.627             0.299         0.227
# Chet Holmgren            ...           1.000             0.359         0.331
# Lauri Markkanen          ...           0.627             0.409         0.237
# Rudy Gobert              ...           1.000             0.359         0.339
# Scottie Barnes           ...           0.627             0.299         0.227
# Jrue Holiday             ...           0.236             0.167         0.136
# Trae Young               ...           0.532             0.373         0.205
# Mikal Bridges            ...           1.000             0.359         0.331
# Derrick White            ...           0.627             0.409         0.237
# Brandon Ingram           ...           0.627             0.409         0.237
# James Harden             ...           0.187             0.144         0.121
#
#                          Scottie Barnes   Jrue Holiday   Trae Young   \
# Luka Doncic                        0.390          0.898        0.129
# Giannis Antetokounmpo              0.470          1.000        0.179
# Shai Gilgeous-Alexander            0.517          1.000        0.189
# Jayson Tatum                       0.468          0.970        0.187
# Stephen Curry                      0.419          1.000        0.201
# Lebron James                       0.030          0.073        0.046
# Joel Embiid                        0.480          1.000        0.186
# Kevin Durant                       0.467          1.000        0.188
# Anthony Edwards                    0.329          1.000        0.042
# Victor Wembenyama                  0.441          0.922        0.216
# Jalen Brunson                      0.422          0.769        0.218
# Anthony Davis                      0.284          0.801        0.090
# Jaylen Brown                       0.467          1.000        0.188
# Devin Booker                       0.466          1.000        0.184
# Tyrese Haliburton                  0.193          0.579        0.004
# Donovan Mitchell                   0.469          0.957        0.183
# Bam Adebayo                        0.485          1.000        0.182
# Tyrese Maxey                       0.422          0.769        0.218
# Ja Morant                          0.410          0.705        0.222
# Paul George                        0.322          1.000        0.089
# Kawhi Leonard                      0.466          1.000        0.147
# Damian Lillard                     0.470          1.000        0.179
# Paolo Banchero                     0.422          0.769        0.218
# Kyrie Irving                       0.513          1.000        0.192
# De'Aaron Fox                       0.441          0.922        0.216
# Zion Williamson                    0.468          0.970        0.187
# Jimmy Butler                       0.513          1.000        0.192
# Domantas Sabonis                   0.351          1.000        0.097
# Karl-Anthony Towns                 0.471          1.000        0.174
# Jamal Murray                       0.517          1.000        0.189
# Chet Holmgren                      0.414          0.920        0.145
# Lauri Markkanen                    0.441          0.922        0.216
# Rudy Gobert                        0.436          1.000        0.151
# Scottie Barnes                     0.517          1.000        0.189
# Jrue Holiday                       0.485          1.000        0.182
# Trae Young                         0.407          0.846        0.228
# Mikal Bridges                      0.414          0.920        0.145
# Derrick White                      0.441          0.922        0.216
# Brandon Ingram                     0.441          0.922        0.216
# James Harden                       0.468          0.970        0.187
#
#                          Mikal Bridges   Derrick White  Brandon Ingram   \
# Luka Doncic                       0.486          0.381            0.206
# Giannis Antetokounmpo             0.172          0.322            0.124
# Shai Gilgeous-Alexander           0.486          0.539            0.308
# Jayson Tatum                      0.161          0.320            0.125
# Stephen Curry                     0.166          0.319            0.128
# Lebron James                      0.022          0.019            0.026
# Joel Embiid                       0.193          0.346            0.143
# Kevin Durant                      0.166          0.326            0.127
# Anthony Edwards                   0.207          0.147            0.043
# Victor Wembenyama                 0.740          0.671            0.451
# Jalen Brunson                     0.616          0.600            0.416
# Anthony Davis                     0.280          0.188            0.076
# Jaylen Brown                      0.166          0.326            0.127
# Devin Booker                      0.163          0.329            0.123
# Tyrese Haliburton                 0.141          0.030            0.006
# Donovan Mitchell                  0.156          0.320            0.120
# Bam Adebayo                       0.202          0.357            0.147
# Tyrese Maxey                      0.616          0.600            0.416
# Ja Morant                         0.552          0.550            0.389
# Paul George                       0.175          0.246            0.086
# Kawhi Leonard                     0.594          0.552            0.313
# Damian Lillard                    0.172          0.322            0.124
# Paolo Banchero                    0.616          0.600            0.416
# Kyrie Irving                      0.486          0.533            0.307
# De'Aaron Fox                      0.740          0.671            0.451
# Zion Williamson                   0.161          0.320            0.125
# Jimmy Butler                      0.486          0.533            0.307
# Domantas Sabonis                  0.294          0.213            0.079
# Karl-Anthony Towns                0.171          0.324            0.120
# Jamal Murray                      0.486          0.539            0.308
# Chet Holmgren                     0.752          0.608            0.374
# Lauri Markkanen                   0.740          0.671            0.451
# Rudy Gobert                       0.744          0.616            0.370
# Scottie Barnes                    0.486          0.539            0.308
# Jrue Holiday                      0.202          0.357            0.147
# Trae Young                        0.660          0.609            0.422
# Mikal Bridges                     0.752          0.608            0.374
# Derrick White                     0.740          0.671            0.451
# Brandon Ingram                    0.740          0.671            0.451
# James Harden                      0.161          0.320            0.125
#
#                          James Harden
# Luka Doncic                      0.252
# Giannis Antetokounmpo            0.672
# Shai Gilgeous-Alexander          0.434
# Jayson Tatum                     0.689
# Stephen Curry                    0.643
# Lebron James                     0.101
# Joel Embiid                      0.672
# Kevin Durant                     0.688
# Anthony Edwards                  0.211
# Victor Wembenyama                0.198
# Jalen Brunson                    0.193
# Anthony Davis                    0.234
# Jaylen Brown                     0.688
# Devin Booker                     0.673
# Tyrese Haliburton                0.022
# Donovan Mitchell                 0.677
# Bam Adebayo                      0.653
# Tyrese Maxey                     0.193
# Ja Morant                        0.226
# Paul George                      0.427
# Kawhi Leonard                    0.308
# Damian Lillard                   0.672
# Paolo Banchero                   0.193
# Kyrie Irving                     0.447
# De'Aaron Fox                     0.198
# Zion Williamson                  0.689
# Jimmy Butler                     0.447
# Domantas Sabonis                 0.292
# Karl-Anthony Towns               0.655
# Jamal Murray                     0.434
# Chet Holmgren                    0.170
# Lauri Markkanen                  0.198
# Rudy Gobert                      0.214
# Scottie Barnes                   0.434
# Jrue Holiday                     0.653
# Trae Young                       0.229
# Mikal Bridges                    0.170
# Derrick White                    0.198
# Brandon Ingram                   0.198
# James Harden                     0.689
#
# [40 rows x 40 columns]
#
# Full matrix saved to 'model_4_cross_efficiency_matrix.csv'

# %%
# Display and Save Final Ranked Scores
print("\n--- Final Cross-Efficiency Ranked Scores ---")
m4_scores_df['Rank'] = m4_scores_df['Cross_Efficiency_Score'].rank(method='min', ascending=False).astype(int)
m4_scores_df = m4_scores_df.sort_values(by='Cross_Efficiency_Score', ascending=False).reset_index(drop=True)
print(tabulate(m4_scores_df, headers='keys', tablefmt='fancy_grid', showindex=False))
m4_scores_df.to_csv('cross_efficiency_ranking.csv', index=False)
print("\nFinal ranking saved to 'cross_efficiency_ranking.csv'")
# Out:
# --- Final Cross-Efficiency Ranked Scores ---
# ╒═════════════════════════╤══════════════════════════╤════════╕
# │ Player                  │   Cross_Efficiency_Score │   Rank │
# ╞═════════════════════════╪══════════════════════════╪════════╡
# │ Anthony Edwards         │                 0.932979 │      1 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Jrue Holiday            │                 0.913156 │      2 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Lebron James            │                 0.76655  │      3 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Victor Wembenyama       │                 0.746328 │      4 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Shai Gilgeous-Alexander │                 0.707993 │      5 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Kawhi Leonard           │                 0.655204 │      6 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Devin Booker            │                 0.645433 │      7 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Karl-Anthony Towns      │                 0.595049 │      8 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Kevin Durant            │                 0.581088 │      9 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Tyrese Haliburton       │                 0.530796 │     10 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Chet Holmgren           │                 0.525485 │     11 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Jalen Brunson           │                 0.495852 │     12 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Jayson Tatum            │                 0.475889 │     13 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Stephen Curry           │                 0.453158 │     14 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Derrick White           │                 0.43038  │     15 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Scottie Barnes          │                 0.426081 │     16 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Paul George             │                 0.415314 │     17 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Mikal Bridges           │                 0.401236 │     18 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ James Harden            │                 0.400902 │     19 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Giannis Antetokounmpo   │                 0.386993 │     20 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Bam Adebayo             │                 0.353785 │     21 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Domantas Sabonis        │                 0.343508 │     22 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Luka Doncic             │                 0.335437 │     23 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Anthony Davis           │                 0.329886 │     24 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Ja Morant               │                 0.328256 │     25 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Donovan Mitchell        │                 0.323893 │     26 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Damian Lillard          │                 0.323041 │     27 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Tyrese Maxey            │                 0.310418 │     28 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Kyrie Irving            │                 0.280864 │     29 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Jamal Murray            │                 0.266943 │     30 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Paolo Banchero          │                 0.25227  │     31 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Zion Williamson         │                 0.250392 │     32 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Jaylen Brown            │                 0.243786 │     33 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Brandon Ingram          │                 0.240283 │     34 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Lauri Markkanen         │                 0.234415 │     35 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Joel Embiid             │                 0.219627 │     36 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ De'Aaron Fox            │                 0.19244  │     37 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Rudy Gobert             │                 0.18395  │     38 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Trae Young              │                 0.170182 │     39 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Jimmy Butler            │                 0.15095  │     40 │
# ╘═════════════════════════╧══════════════════════════╧════════╛
#
# Final ranking saved to 'cross_efficiency_ranking.csv'
