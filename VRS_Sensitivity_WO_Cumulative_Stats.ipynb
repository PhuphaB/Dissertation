# %%
# !apt-get install -y -qq glpk-utils
# !pip install pulp
import pandas as pd
import numpy as np
from pulp import LpProblem, LpVariable, lpSum, LpMaximize, LpStatus, GLPK
from tabulate import tabulate
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# (Reading database ... 126371 files and directories currently installed.)
# Preparing to unpack .../libsuitesparseconfig5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../libamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../libcolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libglpk40:amd64.
# Preparing to unpack .../libglpk40_5.0-1_amd64.deb ...
# Unpacking libglpk40:amd64 (5.0-1) ...
# Selecting previously unselected package glpk-utils.
# Preparing to unpack .../glpk-utils_5.0-1_amd64.deb ...
# Unpacking glpk-utils (5.0-1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libglpk40:amd64 (5.0-1) ...
# Setting up glpk-utils (5.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# Collecting pulp
#   Downloading pulp-3.2.2-py3-none-any.whl.metadata (6.9 kB)
# Downloading pulp-3.2.2-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 90.0 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-3.2.2

# %%
# Load data from the specified URL
url = 'https://raw.githubusercontent.com/PhuphaB/Dissertation/main/ESPN_Top_40_Players.csv'
data = pd.read_csv(url, skiprows=[0]) # Skip the first row

# %%
# Rename columns
data.columns = [
    'ESPN_Ranking', 'Player', 'Team', 'Team_IG_Followers_M',
    'PER', 'Minutes_Played', 'Clutch_PPG', 'Win_Shares',
    'True_Shooting_Pct', 'IG_Growth_Pct', 'IG_Engagement_Pct',
    'Player_IG_Followers_M', 'Google_Trends_Score', 'All_Star_Votes_M'
]

# Check updated column names
data.head()
# Out:
#    ESPN_Ranking                   Player                   Team  \
# 0             2              Luka Doncic     Los Angeles Lakers
# 1             3    Giannis Antetokounmpo       Milwaukee Bucks
# 2             4  Shai Gilgeous-Alexander  Oklahoma City Thunder
# 3             5             Jayson Tatum         Boston Celtics
# 4             6           Stephen Curry   Golden State Warriors
#
#    Team_IG_Followers_M   PER  Minutes_Played  Clutch_PPG  Win_Shares  \
# 0                25.32  24.1            1769         1.9         5.9
# 1                 5.50  30.5            2289         2.9        11.5
# 2                 6.16  30.7            2598         3.0        16.7
# 3                 8.46  21.7            2624         3.0         9.5
# 4                32.72  21.5            2252         3.6         7.9
#
#    True_Shooting_Pct  IG_Growth_Pct  IG_Engagement_Pct  Player_IG_Followers_M  \
# 0               58.7          24.00               7.12                  10.49
# 1               62.5           1.26               1.79                  15.99
# 2               63.7          69.19              10.73                   4.01
# 3               58.2          10.60               5.22                   7.30
# 4               61.8           6.20               0.77                  58.11
#
#    Google_Trends_Score  All_Star_Votes_M
# 0                 5.58              2.03
# 1                32.74              4.44
# 2                41.52              3.15
# 3                32.02              3.61
# 4                29.29              2.34

# %%
def run_vrs_dea_with_ar(inputs_df, outputs_df, ar_constraint=False, ar_lower_bound=0.05):
    """
    Runs an output-oriented VRS DEA to get the optimal weights for each player.
    Includes an optional Assurance Region (AR) constraint.
    """
    inputs = inputs_df.values
    outputs = outputs_df.values
    player_names = data['Player'].values
    num_players = len(player_names)
    num_inputs = inputs.shape[1]
    num_outputs = outputs.shape[1]
    optimal_weights = {}

    for i in range(num_players):
        prob = LpProblem(f"VRS_AR_DEA_Player_{i}", LpMaximize)
        u = [LpVariable(f"u_{r}_{i}", lowBound=0) for r in range(num_outputs)]
        v = [LpVariable(f"v_{s}_{i}", lowBound=0) for s in range(num_inputs)]
        u0 = LpVariable(f"u0_{i}") # VRS Intercept

        prob += lpSum(u[r] * outputs[i, r] for r in range(num_outputs)) - u0
        prob += lpSum(v[s] * inputs[i, s] for s in range(num_inputs)) == 1

        for j in range(num_players):
            prob += lpSum(u[r] * outputs[j, r] for r in range(num_outputs)) - \
                    lpSum(v[s] * inputs[j, s] for s in range(num_inputs)) - u0 <= 0

        if ar_constraint:
            sum_of_u_weights = lpSum(u)
            for r in range(num_outputs):
                prob += u[r] >= ar_lower_bound * sum_of_u_weights

        prob.solve(GLPK(msg=False))

        if LpStatus[prob.status] == 'Optimal':
            optimal_weights[player_names[i]] = {'u': [var.value() for var in u], 'v': [var.value() for var in v]}
        else:
            optimal_weights[player_names[i]] = None

    return optimal_weights

def calculate_cross_efficiency(inputs_df, outputs_df, all_weights):
    """Calculates the cross-efficiency matrix and final average scores."""
    inputs = inputs_df.values
    outputs = outputs_df.values
    player_names = data['Player'].values
    num_players = len(player_names)
    cross_efficiency_matrix = np.zeros((num_players, num_players))

    for i, i_player_name in enumerate(player_names):
        weights = all_weights.get(i_player_name)
        if weights is None: continue
        evaluator_u, evaluator_v = weights['u'], weights['v']

        for j, j_player_name in enumerate(player_names):
            weighted_outputs = np.sum(outputs[j, :] * evaluator_u)
            weighted_inputs = np.sum(inputs[j, :] * evaluator_v)
            score = weighted_outputs / weighted_inputs if weighted_inputs != 0 else 0
            cross_efficiency_matrix[i, j] = score

    final_cross_scores = np.mean(cross_efficiency_matrix, axis=0)
    scores_df = pd.DataFrame({'Player': player_names, 'Cross_Efficiency_Score': final_cross_scores})
    matrix_df = pd.DataFrame(cross_efficiency_matrix, index=player_names, columns=player_names)
    return matrix_df, scores_df

# %%
# Define the inputs and outputs for Definitive Model
input_cols = ['PER','True_Shooting_Pct', 'Clutch_PPG']
output_cols = ['IG_Growth_Pct', 'IG_Engagement_Pct', 'Player_IG_Followers_M', 'All_Star_Votes_M', 'Google_Trends_Score']
model1_inputs = data[input_cols]
model1_outputs = data[output_cols]

# First, run the VRS DEA with the AR constraint to get the optimal weights
print("--- Running VRS DEA with AR constraint to calculate optimal weights ---")
model1_vrs_ar_weights = run_vrs_dea_with_ar(
    model1_inputs,
    model1_outputs,
    ar_constraint=True, # This is the key change to activate the AR constraint
    ar_lower_bound=0.05
)
print("Optimal weights calculated.\n")

# Now, use those weights to calculate cross-efficiency
print("--- Calculating Cross-Efficiency Matrix and Scores ---")
matrix_df, scores_df = calculate_cross_efficiency(model1_inputs, model1_outputs, model1_vrs_ar_weights)
print("Cross-efficiency analysis complete.\n")
# Out:
# --- Running VRS DEA with AR constraint to calculate optimal weights ---
# Optimal weights calculated.
#
# --- Calculating Cross-Efficiency Matrix and Scores ---
# Cross-efficiency analysis complete.

# %%
# --- Display and Save the Full Matrix ---
print("\n--- Full Cross-Efficiency Matrix (VRS Definitive Model with AR) ---")
print("Rows = The player whose weights are being used (Evaluator)")
print("Columns = The player being scored (Evaluatee)\n")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
print(matrix_df.round(4))
matrix_df.to_csv('definitive_model_vrs_ar_cross_efficiency_full_matrix.csv')
print("\nFull matrix saved to 'definitive_model_vrs_ar_cross_efficiency_full_matrix.csv'")


# --- Display and Save Final Ranked Scores ---
print("\n--- Final Cross-Efficiency Ranked Scores (VRS Definitive Model with AR) ---")
scores_df['Rank'] = scores_df['Cross_Efficiency_Score'].rank(method='min', ascending=False).astype(int)
scores_df_sorted = scores_df.sort_values(by='Rank')
print(tabulate(scores_df_sorted, headers='keys', tablefmt='fancy_grid', showindex=False))
scores_df_sorted.to_csv('definitive_model_vrs_ar_cross_efficiency_ranking.csv', index=False)
print("\nFinal ranking saved to 'definitive_model_vrs_ar_cross_efficiency_ranking.csv'")
# Out:
# --- Full Cross-Efficiency Matrix (VRS Definitive Model with AR) ---
# Rows = The player whose weights are being used (Evaluator)
# Columns = The player being scored (Evaluatee)
#
#                          Luka Doncic  Giannis Antetokounmpo  \
# Luka Doncic                   0.0570                 0.0357
# Giannis Antetokounmpo         0.0358                 0.1076
# Shai Gilgeous-Alexander       0.0845                 0.0749
# Jayson Tatum                  0.0358                 0.1076
# Stephen Curry                 0.0325                 0.1053
# Lebron James                  0.1093                 0.1026
# Joel Embiid                   0.0119                 0.0156
# Kevin Durant                  0.0358                 0.1076
# Anthony Edwards               0.2520                 0.1993
# Victor Wembenyama             0.4723                 0.1612
# Jalen Brunson                 0.0748                 0.0360
# Anthony Davis                 0.0210                 0.0281
# Jaylen Brown                 -0.0000                -0.0000
# Devin Booker                  0.1634                 0.5598
# Tyrese Haliburton             0.2055                 0.0247
# Donovan Mitchell              0.0325                 0.1053
# Bam Adebayo                  -0.0000                -0.0000
# Tyrese Maxey                  0.0441                 0.0638
# Ja Morant                     0.0113                 0.0152
# Paul George                   0.0437                 0.0531
# Kawhi Leonard                 0.1026                 0.0486
# Damian Lillard                0.0283                 0.0849
# Paolo Banchero                0.0759                 0.0380
# Kyrie Irving                  0.0121                 0.0159
# De'Aaron Fox                  0.0190                 0.0091
# Zion Williamson               0.0119                 0.0156
# Jimmy Butler                  0.0113                 0.0152
# Domantas Sabonis              0.0198                 0.0032
# Karl-Anthony Towns            0.2447                 0.7370
# Jamal Murray                  0.0000                 0.0000
# Chet Holmgren                 0.2365                 0.0825
# Lauri Markkanen               0.0190                 0.0091
# Rudy Gobert                   0.0000                 0.0000
# Scottie Barnes                0.0198                 0.0032
# Jrue Holiday                  0.1345                 0.3629
# Trae Young                    0.0121                 0.0159
# Mikal Bridges                -0.0000                -0.0000
# Derrick White                 0.0878                 0.0428
# Brandon Ingram                0.0190                 0.0091
# James Harden                  0.0325                 0.1053
#
#                          Shai Gilgeous-Alexander  Jayson Tatum  \
# Luka Doncic                               0.0842        0.0468
# Giannis Antetokounmpo                     0.1383        0.1089
# Shai Gilgeous-Alexander                   0.1773        0.1051
# Jayson Tatum                              0.1383        0.1089
# Stephen Curry                             0.1339        0.1064
# Lebron James                              0.0632        0.0564
# Joel Embiid                               0.0098        0.0094
# Kevin Durant                              0.1383        0.1089
# Anthony Edwards                           0.5712        0.2312
# Victor Wembenyama                         0.6614        0.3101
# Jalen Brunson                             0.1319        0.0648
# Anthony Davis                             0.0394        0.0270
# Jaylen Brown                             -0.0000       -0.0000
# Devin Booker                              0.7497        0.5682
# Tyrese Haliburton                         0.3710        0.0693
# Donovan Mitchell                          0.1339        0.1064
# Bam Adebayo                              -0.0000       -0.0000
# Tyrese Maxey                              0.0896        0.0630
# Ja Morant                                 0.0095        0.0093
# Paul George                               0.0411        0.0410
# Kawhi Leonard                             0.1657        0.0844
# Devin Booker                    0.2935          0.2055            0.1400
# Tyrese Haliburton               0.0214          0.7706            0.0060
# Donovan Mitchell                0.0504          0.0259            0.0225
# Bam Adebayo                    -0.0000         -0.0000           -0.0000
# Tyrese Maxey                    0.0138          0.0239            0.0083
# Ja Morant                       0.0024          0.0029            0.0011
# Paul George                     0.0161          0.0234            0.0085
# Kawhi Leonard                   0.0530          0.1237            0.0663
# Damian Lillard                  0.0395          0.0215            0.0178
# Paolo Banchero                  0.0411          0.0828            0.0499
# Kyrie Irving                    0.0027          0.0032            0.0013
# De'Aaron Fox                    0.0110          0.0220            0.0137
# Zion Williamson                 0.0025          0.0032            0.0012
# Jimmy Butler                    0.0024          0.0029            0.0011
# Domantas Sabonis                0.0027          0.0209            0.0006
# Karl-Anthony Towns              0.3668          0.2759            0.1768
# Jamal Murray                    0.0000          0.0000           -0.0000
# Chet Holmgren                   0.0931          1.0000            0.1369
# Lauri Markkanen                 0.0110          0.0220            0.0137
# Rudy Gobert                     0.0000          0.0000            0.0000
# Scottie Barnes                  0.0027          0.0209            0.0006
# Jrue Holiday                    0.1953          0.5107            0.1056
# Trae Young                      0.0027          0.0032            0.0013
# Mikal Bridges                  -0.0000         -0.0000           -0.0000
# Derrick White                   0.0492          0.0985            0.0604
# Brandon Ingram                  0.0110          0.0220            0.0137
# James Harden                    0.0504          0.0259            0.0225
#
#                          Rudy Gobert   Scottie Barnes   Jrue Holiday   \
# Luka Doncic                    0.0185           0.0430         0.0666
# Giannis Antetokounmpo          0.0167           0.0752         0.1440
# Shai Gilgeous-Alexander        0.0329           0.0937         0.1517
# Jayson Tatum                   0.0167           0.0752         0.1440
# Stephen Curry                  0.0168           0.0746         0.1434
# Lebron James                   0.0289           0.0296         0.0808
# Joel Embiid                    0.0012           0.0039         0.0068
# Kevin Durant                   0.0167           0.0752         0.1440
# Anthony Edwards                0.1313           0.3311         1.0122
# Victor Wembenyama              0.2830           0.4145         0.9771
# Jalen Brunson                  0.0246           0.0665         0.0986
# Anthony Davis                  0.0030           0.0152         0.0291
# Jaylen Brown                  -0.0000          -0.0000        -0.0000
# Devin Booker                   0.1329           0.4493         1.0000
# Tyrese Haliburton              0.0126           0.1934         0.5787
# Donovan Mitchell               0.0168           0.0746         0.1434
# Bam Adebayo                   -0.0000          -0.0000        -0.0000
# Tyrese Maxey                   0.0055           0.0334         0.0585
# Ja Morant                      0.0011           0.0038         0.0064
# Paul George                    0.0114           0.0246         0.0666
# Kawhi Leonard                  0.0389           0.0867         0.1341
# Damian Lillard                 0.0137           0.0588         0.1147
# Paolo Banchero                 0.0264           0.0662         0.0962
# Kyrie Irving                   0.0012           0.0042         0.0073
# De'Aaron Fox                   0.0073           0.0174         0.0270
# Zion Williamson                0.0012           0.0039         0.0068
# Jimmy Butler                   0.0011           0.0038         0.0064
# Domantas Sabonis               0.0005           0.0225         0.0439
# Karl-Anthony Towns             0.1645           0.5743         1.2612
# Jamal Murray                   0.0000           0.0000         0.0000
# Chet Holmgren                  0.2286           0.1663         0.3915
# Lauri Markkanen                0.0073           0.0174         0.0270
# Rudy Gobert                    0.0000           0.0000         0.0000
# Scottie Barnes                 0.0005           0.0225         0.0439
# Jrue Holiday                   0.2460           0.3195         1.0000
# Trae Young                     0.0012           0.0042         0.0073
# Mikal Bridges                 -0.0000          -0.0000        -0.0000
# Derrick White                  0.0320           0.0783         0.1177
# Brandon Ingram                 0.0073           0.0174         0.0270
# James Harden                   0.0168           0.0746         0.1434
#
#                          Trae Young   Mikal Bridges   Derrick White  \
# Luka Doncic                   0.0223          0.0505         0.0514
# Giannis Antetokounmpo         0.0354          0.0251         0.0495
# Shai Gilgeous-Alexander       0.0438          0.0855         0.0996
# Jayson Tatum                  0.0354          0.0251         0.0495
# Stephen Curry                 0.0349          0.0239         0.0495
# Lebron James                  0.0240          0.0250         0.0168
# Joel Embiid                   0.0053          0.0020         0.0020
# Kevin Durant                  0.0354          0.0251         0.0495
# Anthony Edwards               0.0423          0.2096         0.1484
# Victor Wembenyama             0.1166          0.6659         0.5019
# Jalen Brunson                 0.0308          0.0738         0.0764
# Anthony Davis                 0.0073          0.0095         0.0086
# Jaylen Brown                 -0.0000         -0.0000        -0.0000
# Devin Booker                  0.1537          0.1640         0.3161
# Tyrese Haliburton             0.0045          0.1406         0.0304
# Donovan Mitchell              0.0349          0.0239         0.0495
# Bam Adebayo                  -0.0000         -0.0000        -0.0000
# Tyrese Maxey                  0.0187          0.0190         0.0184
# Ja Morant                     0.0054          0.0019         0.0019
# Paul George                   0.0182          0.0158         0.0168
# Kawhi Leonard                 0.0386          0.1079         0.1093
# Damian Lillard                0.0276          0.0194         0.0391
# Paolo Banchero                0.0330          0.0771         0.0816
# Kyrie Irving                  0.0060          0.0022         0.0021
# De'Aaron Fox                  0.0087          0.0216         0.0223
# Zion Williamson               0.0053          0.0020         0.0020
# Jimmy Butler                  0.0054          0.0019         0.0019
# Domantas Sabonis              0.0008          0.0103         0.0031
# Karl-Anthony Towns            0.2021          0.2182         0.3986
# Jamal Murray                  0.0000          0.0000         0.0000
# Chet Holmgren                 0.0471          0.3251         0.2375
# Lauri Markkanen               0.0087          0.0216         0.0223
# Rudy Gobert                   0.0000          0.0000         0.0000
# Scottie Barnes                0.0008          0.0103         0.0031
# Jrue Holiday                  0.0785          0.1684         0.2481
# Trae Young                    0.0060          0.0022         0.0021
# Mikal Bridges                -0.0000         -0.0000        -0.0000
# Derrick White                 0.0392          0.0943         0.0987
# Brandon Ingram                0.0087          0.0216         0.0223
# James Harden                  0.0349          0.0239         0.0495
#
#                          Brandon Ingram   James Harden
# Luka Doncic                       0.0368         0.0290
# Giannis Antetokounmpo             0.0206         0.1143
# Shai Gilgeous-Alexander           0.0642         0.0725
# Jayson Tatum                      0.0206         0.1143
# Stephen Curry                     0.0206         0.1158
# Lebron James                      0.0197         0.0830
# Joel Embiid                       0.0028         0.0131
# Kevin Durant                      0.0206         0.1143
# Anthony Edwards                   0.0430         0.2130
# Victor Wembenyama                 0.3010         0.1463
# Jalen Brunson                     0.0541         0.0290
# Anthony Davis                     0.0040         0.0146
# Jaylen Brown                     -0.0000        -0.0000
# Devin Booker                      0.1139         0.6240
# Tyrese Haliburton                 0.0057         0.0223
# Donovan Mitchell                  0.0206         0.1158
# Bam Adebayo                      -0.0000        -0.0000
# Tyrese Maxey                      0.0089         0.0335
# Ja Morant                         0.0027         0.0127
# Paul George                       0.0132         0.0566
# Kawhi Leonard                     0.0754         0.0388
# Damian Lillard                    0.0166         0.0923
# Paolo Banchero                    0.0581         0.0305
# Kyrie Irving                      0.0030         0.0141
# De'Aaron Fox                      0.0158         0.0080
# Zion Williamson                   0.0028         0.0131
# Jimmy Butler                      0.0027         0.0127
# Domantas Sabonis                  0.0007         0.0030
# Karl-Anthony Towns                0.1460         0.7843
# Jamal Murray                      0.0000         0.0000
# Chet Holmgren                     0.1368         0.0640
# Lauri Markkanen                   0.0158         0.0080
# Rudy Gobert                       0.0000         0.0000
# Scottie Barnes                    0.0007         0.0030
# Jrue Holiday                      0.0776         0.3957
# Trae Young                        0.0030         0.0141
# Mikal Bridges                    -0.0000        -0.0000
# Derrick White                     0.0700         0.0361
# Brandon Ingram                    0.0158         0.0080
# James Harden                      0.0206         0.1158
#
# Full matrix saved to 'definitive_model_vrs_ar_cross_efficiency_full_matrix.csv'
#
# --- Final Cross-Efficiency Ranked Scores (VRS Definitive Model with AR) ---
# ╒═════════════════════════╤══════════════════════════╤════════╕
# │ Player                  │   Cross_Efficiency_Score │   Rank │
# ╞═════════════════════════╪══════════════════════════╪════════╡
# │ Anthony Edwards         │                0.219626  │      1 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Jrue Holiday            │                0.207677  │      2 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Lebron James            │                0.190895  │      3 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Shai Gilgeous-Alexander │                0.158651  │      4 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Victor Wembenyama       │                0.152899  │      5 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Tyrese Haliburton       │                0.148503  │      6 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Kawhi Leonard           │                0.147299  │      7 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Chet Holmgren           │                0.143089  │      8 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Devin Booker            │                0.141762  │      9 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Karl-Anthony Towns      │                0.138193  │     10 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Kevin Durant            │                0.116224  │     11 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Jalen Brunson           │                0.104237  │     12 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Stephen Curry           │                0.104214  │     13 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Paul George             │                0.0984903 │     14 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Jayson Tatum            │                0.0973714 │     15 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Scottie Barnes          │                0.0903668 │     16 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ James Harden            │                0.0891404 │     17 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Giannis Antetokounmpo   │                0.0875418 │     18 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Domantas Sabonis        │                0.0816776 │     19 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Anthony Davis           │                0.073927  │     20 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Bam Adebayo             │                0.0736607 │     21 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Damian Lillard          │                0.0726877 │     22 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Derrick White           │                0.0719963 │     23 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Luka Doncic             │                0.0702515 │     24 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Donovan Mitchell        │                0.0698752 │     25 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Mikal Bridges           │                0.0678642 │     26 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Tyrese Maxey            │                0.0616619 │     27 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Ja Morant               │                0.0606798 │     28 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Kyrie Irving            │                0.0601911 │     29 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Zion Williamson         │                0.0565505 │     30 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Jaylen Brown            │                0.0513964 │     31 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Jamal Murray            │                0.0502687 │     32 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Joel Embiid             │                0.0479327 │     33 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Paolo Banchero          │                0.0456333 │     34 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Rudy Gobert             │                0.039124  │     35 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Lauri Markkanen         │                0.0364343 │     36 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Brandon Ingram          │                0.0358624 │     37 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Jimmy Butler            │                0.031916  │     38 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ Trae Young              │                0.030504  │     39 │
# ├─────────────────────────┼──────────────────────────┼────────┤
# │ De'Aaron Fox            │                0.0267547 │     40 │
# ╘═════════════════════════╧══════════════════════════╧════════╛
#
# Final ranking saved to 'definitive_model_vrs_ar_cross_efficiency_ranking.csv'
